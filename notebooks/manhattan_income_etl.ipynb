# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\bryan\Downloads\manhattan_median_income.xlsx')

# %%
df['Label'] = df['Label'].str.replace('ZCTA5 ', '', regex=False)

# %%
df = df.rename(columns={
    'Label': ' ZIP_CODE',
    'Estimate': 'Median_Income'})

# %%
df.to_excel('cleaned_manhattan_median_income.xlsx', index=False)
